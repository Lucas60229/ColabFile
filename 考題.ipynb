# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas60229/Lucaswu/blob/master/%E8%80%83%E9%A1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 掛載gdrive ，載入金鑰
# 上網找出此段程式碼，可以在colab 掛載(mount) google drive

# %%
from google.colab import drive
# 掛載 gdrive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## 掛載成功後，可以像本機磁碟一瓶執行linux 指令查看檔案

# %%
! ls '/content/gdrive/My Drive/'
# Out:
#  Code		   'My cool spreadsheet.gsheet'   Tracks
# 'Colab Notebooks'   PS				  Translation
# 'HF Project'	   'sara 更新講義(ver4.0).rar'	  university

# %% [markdown]
# # 請至以下官網註冊mlab帳號
# https://mlab.com/
#
#
# *  並建立測試用的mongodb db
# *  建立db 使用者帳密

# %% [markdown]
# # 請寫程式，寫入mongodb, 建立以下資料
#
#
# *   二個collection, pay_type, store
# *   分別寫入如下圖資料

# %% [markdown]
# <img src="data:image/png;base64,...">

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient

client = pymongo.MongoClient("mongodb+srv://lucas:asrt7934851@cluster0-tfx0l.gcp.mongodb.net/test?retryWrites=true&w=majority")
db = client.practice
collection_pay = db['pay_type']
pay_type_arr = pd.Series(['信用卡','餐券','電子票證'])
pay = pd.DataFrame({'type': pay_type_arr,})
result = pay.to_dict('result')
collection_pay.insert(result)

collection_store = db['store']
store_name = pd.Series(['台中店','台北店'])
store_area = pd.Series(['台中','台北'])
store_id = pd.Series(['1','2'])
store = pd.DataFrame({ 'name': store_name, 'area': store_area, 'store_id': store_id })
result = store.to_dict('result')
collection_store.insert(result)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# [ObjectId('5e023a944cccd30f2a6657c6'), ObjectId('5e023a944cccd30f2a6657c7')]

# %% [markdown]
# # 接下來一樣使用pymongo
#
#
# *   更新台中店的store_id = 3
# *   新增一個高雄店, area = 高雄，id = 4

# %%
TC = {'name': '台中店'}
find_TC = collection_store.find_one(TC)
find_TC['store_id'] = 3
new_TC = collection_store.update(TC, find_TC)

KH = {
    'name': '高雄店',
    'area': '高雄',
    'store_id': '4'
}
add_KH = collection_store.insert(KH)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   # This is added back by InteractiveShellApp.init_path()
